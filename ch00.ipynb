# %% [markdown]
# > ⚠ **Do not delete or recreate the provided cells** (instructions and answer cells). Write your answers ONLY inside the provided answer cells. If a provided cell is deleted or replaced, your work in that part **may be excluded from grading**. Deleted a cell by accident? Open a FRESH copy of the template from the assignment link and paste your work into the matching answer cells, or use **File → Revision history** to restore. **Save and pin a revision at the end of each section.**

# %% [markdown]
# # <p style="font-family: Arial; font-size:1.4em;color:gold;"> Jupyter Notebook </p>
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*RzxZF0mmXAsMLrIzAWYDSg.png" alt="Drawing" style="width: 400px;"/>
#
# **Name:** *(double-click this cell and type your name here)*
#
# **AVC ID:** *(type your student ID here)*
#
# ---
#
# ### Before you start — save your own copy
#
# If you opened this notebook from GitHub, it is **read only** and nothing you do is saved.
#
# Go to `File` -> `Save a copy in Drive` **first**, and do all your work in that copy.
#
# Without this you have no revision history at all, and the revision part of your grade cannot be recovered afterwards.
#
# ---
#
# ### Run your cells ONE AT A TIME
#
# Click the play button on each cell yourself, from top to bottom.
#
# **Do not use `Runtime` -> `Run all`.**
#
# Colab stores the time each cell was run. `Run all` overwrites every one of those times with a single instant, so the record of the work you actually did disappears - and that record is part of your grade. Running the cells yourself, in order, keeps it intact.

# %% [markdown]
# <!-- @anchor:S1Q1 type=code -->
# ## Task 1 - Run your first cell
#
# **Goal.** Make the cell below print the correct greeting, and run it.
#
# **How.**
# 1. The cell below has a spelling mistake: it prints `Hello Wolrd`.
# 2. Fix the spelling so it prints `Hello World`.
# 3. Run the cell by clicking the small play button on its left (or press `Shift` + `Enter`).
#
# **Expected output:** `Hello World`

# %%
# @answer:S1Q1
print('Hello World')   # <-- fix the spelling in the text, then run this cell

# %% [markdown]
# <!-- @anchor:S1R type=reflect -->
# ### Reflection — Task 1
# In a sentence or two: what does this notebook contain right now, at the moment you pin it as `Task 1`?

# %% [markdown]
# I fixed the spelling mistake by changing “Wolrd” to “World”. The code now prints the correct message.<!-- @answer:S1R -->

# %% [markdown]
# > **Save and pin a revision now** — `File` -> `Save and pin revision` — and name it **`Task 1`**. Do not delete the cells above.

# %% [markdown]
# <!-- @anchor:S2Q1 type=code -->
# ## Task 2 - Add a code cell of your own
#
# **Goal.** Create a new **code** cell and make it print the same greeting.
#
# **How.**
# 1. Click the answer cell below once, press `Esc`, then type `b` to insert a new code cell - or use the `+ Code` button in the toolbar.
# 2. Write a `print` statement that prints `Hello World`.
# 3. Run it with the play button (or `Shift` + `Enter`).
#
# **Expected output:** `Hello World`
#
# > Write your answer in the cell below, or in a new cell you create right under it. Do not delete the cell below.

# %%
# @answer:S2Q1
# your code here

# %% [markdown]
# <!-- @anchor:S2R type=reflect -->
# ### Reflection — Task 2
# In a sentence or two: how is this version different from the one you pinned as `Task 1`?

# %% [markdown]
# <!-- @answer:S2R -->
# *(write your takeaway here — do not delete this cell)*

# %% [markdown]
# > **Save and pin a revision now** — `File` -> `Save and pin revision` — and name it **`Task 2`**. Do not delete the cells above.

# %% [markdown]
# <!-- @anchor:S3Q1 type=explain -->
# ## Task 3 - Add a markdown cell with an image
#
# **Goal.** Create a **markdown** cell (text, not code) that shows an image.
#
# **How.**
# 1. Insert a new cell, then make it a markdown cell: press `Esc` then `m`, or use the `+ Text` button in the toolbar.
# 2. Put an image in it. Copy the pattern from the very first cell of this notebook:
#    `<img src="PASTE_AN_IMAGE_URL_HERE" alt="Drawing" style="width: 400px;"/>`
#    A markdown image works too: `![my image](PASTE_AN_IMAGE_URL_HERE)`
# 3. Run the cell (`Shift` + `Enter`) so it renders as a picture, not as text.
#
# **Expected result:** the picture is visible in your notebook.
#
# > Write your answer in the cell below (double-click it to edit), or in a new markdown cell you create right under it. Do not delete the cell below.

# %% [markdown]
# <!-- @answer:S3Q1 -->
# *(double-click this cell and put your image here - do not delete this cell)*

# %% [markdown]
# <!-- @anchor:S3R type=reflect -->
# ### Reflection — Task 3
# In a sentence or two: how is this version different from `Task 2`? Then, looking at all three pinned revisions together, what do they show about how your work grew?

# %% [markdown]
# <!-- @answer:S3R -->
# *(write your takeaway here — do not delete this cell)*

# %% [markdown]
# > **Save and pin a revision now** — `File` -> `Save and pin revision` — and name it **`Task 3`**. Do not delete the cells above.

# %% [markdown]
# ## Before you submit
#
# 1. Open `File` -> `Revision history` and confirm you have **three pinned revisions**, named `Task 1`, `Task 2` and `Task 3`.
# 2. Check that every code cell in this notebook has been run and shows its output.
# 3. Check that both `Reflection` cells and your name / AVC ID at the top are filled in.
# 4. **Share from INSIDE Colab, not from Google Drive.** You saved a copy in Drive, so this notebook is also a file sitting there - but sharing it from Drive produces the wrong kind of link.
#    - In Colab: `Share` (top right) -> `Anyone with the link` -> change `Viewer` to **`Editor`** -> `Copy link`.
# 5. Paste that link in the Canvas text box. That is the whole submission.

# %% [markdown]
# > **Check the link before you paste it.**
# > It must start with `https://colab.research.google.com/drive/`
# >
# > A link that starts with `https://drive.google.com/file/d/` is the Google Drive one. It **cannot be graded and scores 0** - through it your cell outputs, your revision history and your Editor access cannot be checked. Go back into Colab and share from there.
